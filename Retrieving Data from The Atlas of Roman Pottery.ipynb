# %% [markdown]
# In this notebook, we walk you through [potboy.py](potbot.py), a small python script that loads up the data from [the Atlas of Roman Pottery](http://potsherds.net) and writes the results to a file. Then, using a regular expression we'll tidy that txt file to a list of urls linking directly to the images. This in turn will be fed to a `wget` command that will download the images.

# %%
# first we load the modules we'll need
from bs4 import BeautifulSoup  #for parsing html
import csv  # for writing to csv
import requests # for loading in html pages on the web
import re # for regular expression searches

# %%
# then we download our target url and pass it to the beautiful soup module, which knows how to parse html

r = requests.get('http://potsherd.net/atlas/Ware/')
soup = BeautifulSoup(r.content, "html5lib")

# %%
# Next, we tell the program to create a new txt file for us to use as our output container:

f = csv.writer(open("urls.txt", "w"))

# %% [markdown]
# Then comes the magic. We tell python, via BeautifulSoup, to look in the html for a table (having studied the html of our target site, we know that the links to the individual ware pages are organized using html table tags) and then grab the information contained in the a tags.

# %%
trs = soup.find_all('tr')
for tr in trs:
    for link in tr.find_all('a', href=re.compile('^Ware')):
        fulllink = link.get ('href')
        print (fulllink) #print in terminal to verify results
        f.writerow(["http://potsherd.net/atlas/" + fulllink])
# Out:
# Ware/AHGW
# Ware/AOMO
# Ware/ARGO
# Ware/B4
# Ware/BB1
# Ware/BB2
# Ware/C189
# Ware/CGBL
# Ware/CGMW
# Ware/CGCC
# Ware/CGSF
# Ware/CGGL
# Ware/CGTS
# Ware/COLC
# Ware/COMO
# Ware/COTS
# Ware/CBMO
# Ware/CRAM
# Ware/EPON
# Ware/DALES
# Ware/DERBY
# Ware/DR1
# Ware/DR2-4
# Ware/DR20
# Ware/SALA
# Ware/EWARE
# Ware/EGTS
# Ware/TNEG
# Ware/EIMO
# Ware/G12
# Ware/GAUL
# Ware/MARM
# Ware/HARS
# Ware/H70
# Ware/ITMO
# Ware/ITTS
# Ware/HOFA
# Ware/MAYN
# Ware/LRGR
# Ware/LIMO
# Ware/L555
# Ware/LEST
# Ware/KOLN
# Ware/LYON
# Ware/MHMO
# Ware/MRCA
# Ware/NVCC
# Ware/NVMO
# Ware/NFMO
# Ware/NFCC
# Ware/NACA
# Ware/NARS
# Ware/NGGW
# Ware/NKSH
# Ware/OXRS
# Ware/OXMO
# Ware/PAS1
# Ware/PRSW
# Ware/PRW1
# Ware/PRW2
# Ware/PRW3
# Ware/PORD
# Ware/RHOD
# Ware/RVMO
# Ware/R527
# Ware/RBBB1
# Ware/RBMO
# Ware/SAVG
# Ware/SVW
# Ware/SOMO
# Ware/SDBB
# Ware/SGTS
# Ware/MOTS
# Ware/SGCC
# Ware/LRSH
# Ware/SEGL
# Ware/SPAN
# Ware/TN
# Ware/TR
# Ware/LOND
# Ware/MOSL
# Ware/VRMO
# Ware/VRW
# Ware/WPMO

# %% [markdown]
# Right-Click on the Jupyter logo at the top left of this page, and open in a new tab. See the `output.txt` file you created? Have a look at it. It's a list of webpages, one for each ware. In the codeblock above we searched for _every_ link on the page, but we did a regular expression search to _only_ keep the ones that led to the page of a particular ware.

# %% [markdown]
# And now we'll build a `wget` command that is respectful of the Atlas' bandwidth and server resources. Our command tells wget to follow the paths in the input file urls.txt, to wait a moment between requests, to limit the amount asked for each time, and to only keep images.
#
# Now, wget crawls the directory structure
#
# When you run this command, you can stop it early by hitting the square stop button in the command ribbon at the top of the page.

# %%
# !wget -w 2 --limit-rate=200k -A jpeg,jpg,bmp,gif,png -i urls.txt
# Out:
# --2018-06-19 13:59:31--  http://potsherd.net/atlas/Ware/AHGW
# Resolving potsherd.net (potsherd.net)... 79.170.44.157
# Connecting to potsherd.net (potsherd.net)|79.170.44.157|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘AHGW.tmp’
#
# AHGW.tmp                [   <=>              ]  16.92K  22.0KB/s    in 0.8s
#
# 2018-06-19 13:59:33 (22.0 KB/s) - ‘AHGW.tmp’ saved [17330]
#
# --2018-06-19 13:59:35--  http://potsherd.net/atlas/Class/COAR
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘COAR.tmp’
#
# COAR.tmp                [   <=>              ]  18.17K  23.7KB/s    in 0.8s
#
# 2018-06-19 13:59:36 (23.7 KB/s) - ‘COAR.tmp’ saved [18605]
#
# --2018-06-19 13:59:38--  http://potsherd.net/atlas/Source/BRIT
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘BRIT.tmp’
#
# BRIT.tmp                [    <=>             ]  26.35K  22.7KB/s    in 1.2s
#
# 2018-06-19 13:59:39 (22.7 KB/s) - ‘BRIT.tmp’ saved [26983]
#
# --2018-06-19 13:59:41--  http://potsherd.net/atlas/Ware/AOMO
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘AOMO.tmp’
#
# AOMO.tmp                [  <=>               ]  11.35K  28.4KB/s    in 0.4s
#
# 2018-06-19 13:59:42 (28.4 KB/s) - ‘AOMO.tmp’ saved [11624]
#
# --2018-06-19 13:59:44--  http://potsherd.net/atlas/Class/MORT
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘MORT.tmp’
#
# MORT.tmp                [   <=>              ]  15.05K  20.0KB/s    in 0.8s
#
# 2018-06-19 13:59:45 (20.0 KB/s) - ‘MORT.tmp’ saved [15407]
#
# --2018-06-19 13:59:47--  http://potsherd.net/atlas/Source/GAUL
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘GAUL.tmp’
#
# GAUL.tmp                [   <=>              ]  17.27K  22.5KB/s    in 0.8s
#
# 2018-06-19 13:59:48 (22.5 KB/s) - ‘GAUL.tmp’ saved [17683]
#
# --2018-06-19 13:59:50--  http://potsherd.net/atlas/Ware/ARGO
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘ARGO.tmp’
#
# ARGO.tmp                [   <=>              ]  13.99K  20.0KB/s    in 0.7s
#
# 2018-06-19 13:59:51 (20.0 KB/s) - ‘ARGO.tmp’ saved [14322]
#
# --2018-06-19 13:59:53--  http://potsherd.net/atlas/Class/FINE
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘FINE.tmp’
#
# FINE.tmp                [    <=>             ]  18.24K  20.0KB/s    in 0.9s
#
# 2018-06-19 13:59:54 (20.0 KB/s) - ‘FINE.tmp’ saved [18678]
#
# --2018-06-19 13:59:56--  http://potsherd.net/atlas/Source/GAUL
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘GAUL.tmp.1’
#
# GAUL.tmp.1              [   <=>              ]  17.27K  22.2KB/s    in 0.8s
#
# 2018-06-19 13:59:57 (22.2 KB/s) - ‘GAUL.tmp.1’ saved [17683]
#
# --2018-06-19 13:59:59--  http://potsherd.net/atlas/Ware/B4
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘B4.tmp’
#
# B4.tmp                  [  <=>               ]  10.94K  27.3KB/s    in 0.4s
#
# 2018-06-19 14:00:00 (27.3 KB/s) - ‘B4.tmp’ saved [11200]
#
# --2018-06-19 14:00:02--  http://potsherd.net/atlas/Class/AMPH
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘AMPH.tmp’
#
# AMPH.tmp                [    <=>             ]  19.37K  20.0KB/s    in 1.0s
#
# 2018-06-19 14:00:03 (20.0 KB/s) - ‘AMPH.tmp’ saved [19832]
#
# --2018-06-19 14:00:05--  http://potsherd.net/atlas/Source/ORIE
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘ORIE.tmp’
#
# ORIE.tmp                [  <=>               ]  10.82K  27.0KB/s    in 0.4s
#
# 2018-06-19 14:00:05 (27.0 KB/s) - ‘ORIE.tmp’ saved [11075]
#
# --2018-06-19 14:00:07--  http://potsherd.net/atlas/Ware/BB1
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘BB1.tmp’
#
# BB1.tmp                 [    <=>             ]  23.14K  20.0KB/s    in 1.2s
#
# 2018-06-19 14:00:09 (20.0 KB/s) - ‘BB1.tmp’ saved [23697]
#
# --2018-06-19 14:00:11--  http://potsherd.net/atlas/Class/COAR
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘COAR.tmp.1’
#
# COAR.tmp.1              [   <=>              ]  18.17K  23.7KB/s    in 0.8s
#
# 2018-06-19 14:00:12 (23.7 KB/s) - ‘COAR.tmp.1’ saved [18605]
#
# --2018-06-19 14:00:14--  http://potsherd.net/atlas/Source/BRIT
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘BRIT.tmp.1’
#
# BRIT.tmp.1              [    <=>             ]  26.35K  22.7KB/s    in 1.2s
#
# 2018-06-19 14:00:15 (22.7 KB/s) - ‘BRIT.tmp.1’ saved [26983]
#
# --2018-06-19 14:00:17--  http://potsherd.net/atlas/Ware/BB2
# Connecting to potsherd.net (potsherd.net)|79.170.44.157|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘BB2.tmp’
#
# BB2.tmp                 [   <=>              ]  16.43K  21.4KB/s    in 0.8s
#
# 2018-06-19 14:00:18 (21.4 KB/s) - ‘BB2.tmp’ saved [16823]
#
# --2018-06-19 14:00:20--  http://potsherd.net/atlas/Class/COAR
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘COAR.tmp.2’
#
# COAR.tmp.2              [   <=>              ]  18.17K  23.7KB/s    in 0.8s
#
# 2018-06-19 14:00:21 (23.7 KB/s) - ‘COAR.tmp.2’ saved [18605]
#
# --2018-06-19 14:00:23--  http://potsherd.net/atlas/Source/BRIT
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘BRIT.tmp.2’
#
# BRIT.tmp.2              [    <=>             ]  26.35K  22.7KB/s    in 1.2s
#
# 2018-06-19 14:00:25 (22.7 KB/s) - ‘BRIT.tmp.2’ saved [26983]
#
# --2018-06-19 14:00:27--  http://potsherd.net/atlas/Ware/C189
# Reusing existing connection to potsherd.net:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘C189.tmp’
#
# C189.tmp                [  <=>               ]  11.78K  29.4KB/s    in 0.4s
#
# 2018-06-19 14:00:27 (29.4 KB/s) - ‘C189.tmp’ saved [12060]
#
# ^C
